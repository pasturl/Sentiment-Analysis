# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/bert

# %%
# %%capture
# !pip install shap
# !pip install interpret
# !pip install nltk
# !pip install wordcloud
# !pip install lightgbm

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import interpret.glassbox
import lightgbm as lgb
import shap
import random
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stopwords = stopwords.words('english')

from preprocess_data import read_dublin_data, read_sentiment_data, preprocess_data
from evaluate import evaluate_model
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Parameters

# %%
N_SAMPLE = 100000
MAX_FEATURES = 15000
N_TWEET_PRINT = 10

# %% [markdown]
# # Read Data

# %%
# %%capture
filename = "/content/gdrive/MyDrive/bert/Sentiment140-train.csv"
df_train = read_sentiment_data(filename)
df_train = df_train.sample(N_SAMPLE).reset_index(drop=True)

# %%
# %%capture
filename = "/content/gdrive/MyDrive/bert/Sentiment140-test.csv"
df_test = read_sentiment_data(filename)

# %%
# %%capture
filename = "/content/gdrive/MyDrive/bert/citypulse.dublin_city_council.test.csv"
df_dublin = read_dublin_data(filename)

# %%
df_train['split'] = "train"
df_test['split'] = "test"
df_all = pd.concat([df_train, df_test])

# %%
df_dublin = preprocess_data(df_dublin, stopwords)
df_train = preprocess_data(df_train, stopwords)
df_test = preprocess_data(df_test, stopwords)
df_all = preprocess_data(df_all, stopwords)

# %%
word_vectorizer = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', sublinear_tf=True, strip_accents='unicode',
                                  stop_words='english', ngram_range=(1, 1), max_features=MAX_FEATURES)
word_vectorizer.fit(df_all['text_clean'])
# Out:
# TfidfVectorizer(max_features=15000, stop_words='english',
#                 strip_accents='unicode', sublinear_tf=True,
#                 token_pattern='\\w{1,}')

# %% [markdown]
# # Split train/test features and target

# %%
train_text = df_all.loc[df_all['split']=="train", "text_clean"]
test_text = df_all.loc[df_all['split']=="test", "text_clean"]
all_text = df_all["text_clean"]
y_train = df_all.loc[df_all['split']=="train", "sentiment"]
y_test = df_all.loc[df_all['split']=="test", "sentiment"]
y_all_text = df_all["sentiment"]

# %%
x_dublin = df_dublin["text_clean"]
y_dublin = df_dublin["sentiment"]

# %%
train_features = word_vectorizer.transform(train_text)
test_features = word_vectorizer.transform(test_text)
all_features = word_vectorizer.transform(all_text)
dublin_features = word_vectorizer.transform(x_dublin)

# %%
df_train_features = pd.DataFrame(data = train_features.toarray())
df_train_features.columns = word_vectorizer.get_feature_names()

df_test_features = pd.DataFrame(data = test_features.toarray())
df_test_features.columns = word_vectorizer.get_feature_names()

df_dublin_features = pd.DataFrame(data = dublin_features.toarray())
df_dublin_features.columns = word_vectorizer.get_feature_names()

# %%
train_lgb = lgb.Dataset(df_train_features, label=y_train)
test_lgb = lgb.Dataset(df_test_features, label=y_test)
dublin_lgb = lgb.Dataset(df_dublin_features, label=y_dublin)

# %% [markdown]
# # Fit LightGBM model

# %%
parameters = {
    'application': 'binary',
    'objective': 'binary',
    'metric': 'auc',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'feature_fraction': 0.7,
    'bagging_fraction': 0.7,
    'bagging_freq': 20,
    'learning_rate': 0.05,
    'verbose': 0
}

model = lgb.train(parameters,
                       train_lgb,
                       valid_sets=test_lgb,
                       num_boost_round=5000,
                       early_stopping_rounds=100)
# Out:
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.217600 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [1]	valid_0's auc: 0.647717
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 0.626321
# [3]	valid_0's auc: 0.624739
# [4]	valid_0's auc: 0.625861
# [5]	valid_0's auc: 0.628173
# [6]	valid_0's auc: 0.638693
# [7]	valid_0's auc: 0.642509
# [8]	valid_0's auc: 0.655037
# [9]	valid_0's auc: 0.6664
# [10]	valid_0's auc: 0.661766
# [11]	valid_0's auc: 0.660992
# [12]	valid_0's auc: 0.664366
# [13]	valid_0's auc: 0.663122
# [14]	valid_0's auc: 0.668539
# [15]	valid_0's auc: 0.670156
# [16]	valid_0's auc: 0.671321
# [17]	valid_0's auc: 0.675381
# [18]	valid_0's auc: 0.678771
# [19]	valid_0's auc: 0.67632
# [20]	valid_0's auc: 0.682397
# [21]	valid_0's auc: 0.684605
# [22]	valid_0's auc: 0.685839
# [23]	valid_0's auc: 0.683475
# [24]	valid_0's auc: 0.684327
# [25]	valid_0's auc: 0.686544
# [26]	valid_0's auc: 0.688022
# [27]	valid_0's auc: 0.687596
# [28]	valid_0's auc: 0.685718
# [29]	valid_0's auc: 0.687674
# [30]	valid_0's auc: 0.6875
# [31]	valid_0's auc: 0.691325
# [32]	valid_0's auc: 0.690039
# [33]	valid_0's auc: 0.691551
# [34]	valid_0's auc: 0.694055
# [35]	valid_0's auc: 0.694872
# [36]	valid_0's auc: 0.695985
# [37]	valid_0's auc: 0.695064
# [38]	valid_0's auc: 0.697002
# [39]	valid_0's auc: 0.696481
# [40]	valid_0's auc: 0.695472
# [41]	valid_0's auc: 0.697559
# [42]	valid_0's auc: 0.70008
# [43]	valid_0's auc: 0.700576
# [44]	valid_0's auc: 0.701706
# [45]	valid_0's auc: 0.701497
# [46]	valid_0's auc: 0.703862
# [47]	valid_0's auc: 0.706122
# [48]	valid_0's auc: 0.709495
# [49]	valid_0's auc: 0.710226
# [50]	valid_0's auc: 0.711617
# [51]	valid_0's auc: 0.71173
# [52]	valid_0's auc: 0.712903
# [53]	valid_0's auc: 0.715286
# [54]	valid_0's auc: 0.717537
# [55]	valid_0's auc: 0.717989
# [56]	valid_0's auc: 0.72025
# [57]	valid_0's auc: 0.718354
# [58]	valid_0's auc: 0.718467
# [59]	valid_0's auc: 0.718615
# [60]	valid_0's auc: 0.718563
# [61]	valid_0's auc: 0.720476
# [62]	valid_0's auc: 0.721076
# [63]	valid_0's auc: 0.722015
# [64]	valid_0's auc: 0.721119
# [65]	valid_0's auc: 0.721736
# [66]	valid_0's auc: 0.722119
# [67]	valid_0's auc: 0.72231
# [68]	valid_0's auc: 0.72451
# [69]	valid_0's auc: 0.724701
# [70]	valid_0's auc: 0.723249
# [71]	valid_0's auc: 0.72344
# [72]	valid_0's auc: 0.724379
# [73]	valid_0's auc: 0.725675
# [74]	valid_0's auc: 0.725205
# [75]	valid_0's auc: 0.726501
# [76]	valid_0's auc: 0.726501
# [77]	valid_0's auc: 0.727092
# [78]	valid_0's auc: 0.72684
# [79]	valid_0's auc: 0.727674
# [80]	valid_0's auc: 0.727831
# [81]	valid_0's auc: 0.727474
# [82]	valid_0's auc: 0.72684
# [83]	valid_0's auc: 0.727205
# [84]	valid_0's auc: 0.726518
# [85]	valid_0's auc: 0.727127
# [86]	valid_0's auc: 0.72704
# [87]	valid_0's auc: 0.726822
# [88]	valid_0's auc: 0.726474
# [89]	valid_0's auc: 0.727031
# [90]	valid_0's auc: 0.728213
# [91]	valid_0's auc: 0.72797
# [92]	valid_0's auc: 0.727639
# [93]	valid_0's auc: 0.728439
# [94]	valid_0's auc: 0.728813
# [95]	valid_0's auc: 0.728205
# [96]	valid_0's auc: 0.728448
# [97]	valid_0's auc: 0.728065
# [98]	valid_0's auc: 0.729022
# [99]	valid_0's auc: 0.72963
# [100]	valid_0's auc: 0.729578
# [101]	valid_0's auc: 0.729622
# [102]	valid_0's auc: 0.731204
# [103]	valid_0's auc: 0.731013
# [104]	valid_0's auc: 0.731413
# [105]	valid_0's auc: 0.730926
# [106]	valid_0's auc: 0.730743
# [107]	valid_0's auc: 0.730908
# [108]	valid_0's auc: 0.730569
# [109]	valid_0's auc: 0.730204
# [110]	valid_0's auc: 0.730317
# [111]	valid_0's auc: 0.730369
# [112]	valid_0's auc: 0.732004
# [113]	valid_0's auc: 0.733421
# [114]	valid_0's auc: 0.733543
# [115]	valid_0's auc: 0.73363
# [116]	valid_0's auc: 0.733508
# [117]	valid_0's auc: 0.733716
# [118]	valid_0's auc: 0.733803
# [119]	valid_0's auc: 0.734847
# [120]	valid_0's auc: 0.735733
# [121]	valid_0's auc: 0.735951
# [122]	valid_0's auc: 0.737829
# [123]	valid_0's auc: 0.739185
# [124]	valid_0's auc: 0.739341
# [125]	valid_0's auc: 0.741098
# [126]	valid_0's auc: 0.740941
# [127]	valid_0's auc: 0.743523
# [128]	valid_0's auc: 0.743506
# [129]	valid_0's auc: 0.74674
# [130]	valid_0's auc: 0.747357
# [131]	valid_0's auc: 0.747227
# [132]	valid_0's auc: 0.748305
# [133]	valid_0's auc: 0.747627
# [134]	valid_0's auc: 0.748331
# [135]	valid_0's auc: 0.749235
# [136]	valid_0's auc: 0.748783
# [137]	valid_0's auc: 0.749365
# [138]	valid_0's auc: 0.7498
# [139]	valid_0's auc: 0.749644
# [140]	valid_0's auc: 0.750539
# [141]	valid_0's auc: 0.750626
# [142]	valid_0's auc: 0.750643
# [143]	valid_0's auc: 0.751191
# [144]	valid_0's auc: 0.751295
# [145]	valid_0's auc: 0.751661
# [146]	valid_0's auc: 0.752078
# [147]	valid_0's auc: 0.751956
# [148]	valid_0's auc: 0.752095
# [149]	valid_0's auc: 0.7518
# [150]	valid_0's auc: 0.750391
# [151]	valid_0's auc: 0.750339
# [152]	valid_0's auc: 0.750356
# [153]	valid_0's auc: 0.750809
# [154]	valid_0's auc: 0.750878
# [155]	valid_0's auc: 0.750965
# [156]	valid_0's auc: 0.751139
# [157]	valid_0's auc: 0.751243
# [158]	valid_0's auc: 0.751452
# [159]	valid_0's auc: 0.751574
# [160]	valid_0's auc: 0.751574
# [161]	valid_0's auc: 0.751087
# [162]	valid_0's auc: 0.751591
# [163]	valid_0's auc: 0.750548
# [164]	valid_0's auc: 0.750548
# [165]	valid_0's auc: 0.750704
# [166]	valid_0's auc: 0.751574
# [167]	valid_0's auc: 0.75027
# [168]	valid_0's auc: 0.7498
# [169]	valid_0's auc: 0.749974
# [170]	valid_0's auc: 0.7506
# [171]	valid_0's auc: 0.750791
# [172]	valid_0's auc: 0.750948
# [173]	valid_0's auc: 0.750861
# [174]	valid_0's auc: 0.750426
# [175]	valid_0's auc: 0.750078
# [176]	valid_0's auc: 0.750235
# [177]	valid_0's auc: 0.74973
# [178]	valid_0's auc: 0.749826
# [179]	valid_0's auc: 0.750017
# [180]	valid_0's auc: 0.750643
# [181]	valid_0's auc: 0.751026
# [182]	valid_0's auc: 0.751461
# [183]	valid_0's auc: 0.751356
# [184]	valid_0's auc: 0.751356
# [185]	valid_0's auc: 0.751408
# [186]	valid_0's auc: 0.7516
# [187]	valid_0's auc: 0.753025
# [188]	valid_0's auc: 0.753373
# [189]	valid_0's auc: 0.753582
# [190]	valid_0's auc: 0.753564
# [191]	valid_0's auc: 0.753686
# [192]	valid_0's auc: 0.754416
# [193]	valid_0's auc: 0.754851
# [194]	valid_0's auc: 0.754747
# [195]	valid_0's auc: 0.754903
# [196]	valid_0's auc: 0.755451
# [197]	valid_0's auc: 0.756016
# [198]	valid_0's auc: 0.755921
# [199]	valid_0's auc: 0.756181
# [200]	valid_0's auc: 0.75646
# [201]	valid_0's auc: 0.756955
# [202]	valid_0's auc: 0.757233
# [203]	valid_0's auc: 0.757494
# [204]	valid_0's auc: 0.75759
# [205]	valid_0's auc: 0.758024
# [206]	valid_0's auc: 0.758285
# [207]	valid_0's auc: 0.75852
# [208]	valid_0's auc: 0.758398
# [209]	valid_0's auc: 0.758972
# [210]	valid_0's auc: 0.759198
# [211]	valid_0's auc: 0.759146
# [212]	valid_0's auc: 0.759181
# [213]	valid_0's auc: 0.759033
# [214]	valid_0's auc: 0.758703
# [215]	valid_0's auc: 0.758946
# [216]	valid_0's auc: 0.758755
# [217]	valid_0's auc: 0.759016
# [218]	valid_0's auc: 0.759328
# [219]	valid_0's auc: 0.759276
# [220]	valid_0's auc: 0.759085
# [221]	valid_0's auc: 0.759172
# [222]	valid_0's auc: 0.759189
# [223]	valid_0's auc: 0.75945
# [224]	valid_0's auc: 0.759485
# [225]	valid_0's auc: 0.759781
# [226]	valid_0's auc: 0.759937
# [227]	valid_0's auc: 0.760094
# [228]	valid_0's auc: 0.760233
# [229]	valid_0's auc: 0.760015
# [230]	valid_0's auc: 0.760537
# [231]	valid_0's auc: 0.760033
# [232]	valid_0's auc: 0.759807
# [233]	valid_0's auc: 0.76038
# [234]	valid_0's auc: 0.760415
# [235]	valid_0's auc: 0.760328
# [236]	valid_0's auc: 0.760085
# [237]	valid_0's auc: 0.760398
# [238]	valid_0's auc: 0.760137
# [239]	valid_0's auc: 0.760102
# [240]	valid_0's auc: 0.760467
# [241]	valid_0's auc: 0.760502
# [242]	valid_0's auc: 0.760633
# [243]	valid_0's auc: 0.760754
# [244]	valid_0's auc: 0.761102
# [245]	valid_0's auc: 0.761267
# [246]	valid_0's auc: 0.761424
# [247]	valid_0's auc: 0.761911
# [248]	valid_0's auc: 0.762676
# [249]	valid_0's auc: 0.763562
# [250]	valid_0's auc: 0.763458
# [251]	valid_0's auc: 0.763389
# [252]	valid_0's auc: 0.763197
# [253]	valid_0's auc: 0.763562
# [254]	valid_0's auc: 0.763049
# [255]	valid_0's auc: 0.763241
# [256]	valid_0's auc: 0.763345
# [257]	valid_0's auc: 0.763154
# [258]	valid_0's auc: 0.763015
# [259]	valid_0's auc: 0.76291
# [260]	valid_0's auc: 0.763119
# [261]	valid_0's auc: 0.764597
# [262]	valid_0's auc: 0.764997
# [263]	valid_0's auc: 0.765206
# [264]	valid_0's auc: 0.765675
# [265]	valid_0's auc: 0.765675
# [266]	valid_0's auc: 0.766179
# [267]	valid_0's auc: 0.766214
# [268]	valid_0's auc: 0.766336
# [269]	valid_0's auc: 0.766631
# [270]	valid_0's auc: 0.766875
# [271]	valid_0's auc: 0.766823
# [272]	valid_0's auc: 0.767466
# [273]	valid_0's auc: 0.767501
# [274]	valid_0's auc: 0.767501
# [275]	valid_0's auc: 0.767935
# [276]	valid_0's auc: 0.768074
# [277]	valid_0's auc: 0.76797
# [278]	valid_0's auc: 0.768144
# [279]	valid_0's auc: 0.768787
# [280]	valid_0's auc: 0.768805
# [281]	valid_0's auc: 0.7691
# [282]	valid_0's auc: 0.768266
# [283]	valid_0's auc: 0.768266
# [284]	valid_0's auc: 0.767866
# [285]	valid_0's auc: 0.768005
# [286]	valid_0's auc: 0.768196
# [287]	valid_0's auc: 0.768422
# [288]	valid_0's auc: 0.768214
# [289]	valid_0's auc: 0.768161
# [290]	valid_0's auc: 0.767979
# [291]	valid_0's auc: 0.767092
# [292]	valid_0's auc: 0.768361
# [293]	valid_0's auc: 0.768587
# [294]	valid_0's auc: 0.769144
# [295]	valid_0's auc: 0.769213
# [296]	valid_0's auc: 0.769952
# [297]	valid_0's auc: 0.769622
# [298]	valid_0's auc: 0.770109
# [299]	valid_0's auc: 0.770178
# [300]	valid_0's auc: 0.769483
# [301]	valid_0's auc: 0.76957
# [302]	valid_0's auc: 0.769292
# [303]	valid_0's auc: 0.76957
# [304]	valid_0's auc: 0.770352
# [305]	valid_0's auc: 0.770509
# [306]	valid_0's auc: 0.770491
# [307]	valid_0's auc: 0.7707
# [308]	valid_0's auc: 0.770561
# [309]	valid_0's auc: 0.770317
# [310]	valid_0's auc: 0.770196
# [311]	valid_0's auc: 0.770274
# [312]	valid_0's auc: 0.770291
# [313]	valid_0's auc: 0.769892
# [314]	valid_0's auc: 0.769857
# [315]	valid_0's auc: 0.770204
# [316]	valid_0's auc: 0.770065
# [317]	valid_0's auc: 0.769996
# [318]	valid_0's auc: 0.770048
# [319]	valid_0's auc: 0.77057
# [320]	valid_0's auc: 0.770657
# [321]	valid_0's auc: 0.770865
# [322]	valid_0's auc: 0.771465
# [323]	valid_0's auc: 0.77143
# [324]	valid_0's auc: 0.771726
# [325]	valid_0's auc: 0.771813
# [326]	valid_0's auc: 0.771274
# [327]	valid_0's auc: 0.771309
# [328]	valid_0's auc: 0.7715
# [329]	valid_0's auc: 0.771656
# [330]	valid_0's auc: 0.771865
# [331]	valid_0's auc: 0.772178
# [332]	valid_0's auc: 0.772265
# [333]	valid_0's auc: 0.772143
# [334]	valid_0's auc: 0.772387
# [335]	valid_0's auc: 0.772317
# [336]	valid_0's auc: 0.772543
# [337]	valid_0's auc: 0.772578
# [338]	valid_0's auc: 0.772804
# [339]	valid_0's auc: 0.7727
# [340]	valid_0's auc: 0.772908
# [341]	valid_0's auc: 0.772613
# [342]	valid_0's auc: 0.772439
# [343]	valid_0's auc: 0.772421
# [344]	valid_0's auc: 0.772456
# [345]	valid_0's auc: 0.772526
# [346]	valid_0's auc: 0.77276
# [347]	valid_0's auc: 0.772534
# [348]	valid_0's auc: 0.772847
# [349]	valid_0's auc: 0.7729
# [350]	valid_0's auc: 0.772987
# [351]	valid_0's auc: 0.77283
# [352]	valid_0's auc: 0.773021
# [353]	valid_0's auc: 0.772952
# [354]	valid_0's auc: 0.77343
# [355]	valid_0's auc: 0.773343
# [356]	valid_0's auc: 0.773499
# [357]	valid_0's auc: 0.77343
# [358]	valid_0's auc: 0.773395
# [359]	valid_0's auc: 0.773621
# [360]	valid_0's auc: 0.773812
# [361]	valid_0's auc: 0.774195
# [362]	valid_0's auc: 0.774265
# [363]	valid_0's auc: 0.774421
# [364]	valid_0's auc: 0.774073
# [365]	valid_0's auc: 0.774073
# [366]	valid_0's auc: 0.774143
# [367]	valid_0's auc: 0.774421
# [368]	valid_0's auc: 0.774351
# [369]	valid_0's auc: 0.774595
# [370]	valid_0's auc: 0.774612
# [371]	valid_0's auc: 0.774421
# [372]	valid_0's auc: 0.774595
# [373]	valid_0's auc: 0.774595
# [374]	valid_0's auc: 0.774751
# [375]	valid_0's auc: 0.774108
# [376]	valid_0's auc: 0.77463
# [377]	valid_0's auc: 0.77469
# [378]	valid_0's auc: 0.774899
# [379]	valid_0's auc: 0.774864
# [380]	valid_0's auc: 0.77509
# [381]	valid_0's auc: 0.774777
# [382]	valid_0's auc: 0.774638
# [383]	valid_0's auc: 0.774725
# [384]	valid_0's auc: 0.774378
# [385]	valid_0's auc: 0.774343
# [386]	valid_0's auc: 0.774065
# [387]	valid_0's auc: 0.774204
# [388]	valid_0's auc: 0.77403
# [389]	valid_0's auc: 0.773856
# [390]	valid_0's auc: 0.77363
# [391]	valid_0's auc: 0.773499
# [392]	valid_0's auc: 0.77336
# [393]	valid_0's auc: 0.773586
# [394]	valid_0's auc: 0.773517
# [395]	valid_0's auc: 0.773552
# [396]	valid_0's auc: 0.773482
# [397]	valid_0's auc: 0.773743
# [398]	valid_0's auc: 0.77376
# [399]	valid_0's auc: 0.773952
# [400]	valid_0's auc: 0.774091
# [401]	valid_0's auc: 0.774221
# [402]	valid_0's auc: 0.774273
# [403]	valid_0's auc: 0.77443
# [404]	valid_0's auc: 0.774638
# [405]	valid_0's auc: 0.774725
# [406]	valid_0's auc: 0.774847
# [407]	valid_0's auc: 0.774917
# [408]	valid_0's auc: 0.775038
# [409]	valid_0's auc: 0.774934
# [410]	valid_0's auc: 0.774882
# [411]	valid_0's auc: 0.77516
# [412]	valid_0's auc: 0.774934
# [413]	valid_0's auc: 0.775369
# [414]	valid_0's auc: 0.775316
# [415]	valid_0's auc: 0.775456
# [416]	valid_0's auc: 0.77549
# [417]	valid_0's auc: 0.77549
# [418]	valid_0's auc: 0.774969
# [419]	valid_0's auc: 0.774708
# [420]	valid_0's auc: 0.774725
# [421]	valid_0's auc: 0.774908
# [422]	valid_0's auc: 0.774421
# [423]	valid_0's auc: 0.773882
# [424]	valid_0's auc: 0.773725
# [425]	valid_0's auc: 0.773482
# [426]	valid_0's auc: 0.773326
# [427]	valid_0's auc: 0.772787
# [428]	valid_0's auc: 0.772561
# [429]	valid_0's auc: 0.772613
# [430]	valid_0's auc: 0.772543
# [431]	valid_0's auc: 0.772908
# [432]	valid_0's auc: 0.772717
# [433]	valid_0's auc: 0.772682
# [434]	valid_0's auc: 0.772839
# [435]	valid_0's auc: 0.772613
# [436]	valid_0's auc: 0.772665
# [437]	valid_0's auc: 0.772787
# [438]	valid_0's auc: 0.772769
# [439]	valid_0's auc: 0.772578
# [440]	valid_0's auc: 0.772647
# [441]	valid_0's auc: 0.772665
# [442]	valid_0's auc: 0.772508
# [443]	valid_0's auc: 0.772421
# [444]	valid_0's auc: 0.772508
# [445]	valid_0's auc: 0.772456
# [446]	valid_0's auc: 0.772526
# [447]	valid_0's auc: 0.772439
# [448]	valid_0's auc: 0.772821
# [449]	valid_0's auc: 0.772682
# [450]	valid_0's auc: 0.772265
# [451]	valid_0's auc: 0.772248
# [452]	valid_0's auc: 0.772161
# [453]	valid_0's auc: 0.772387
# [454]	valid_0's auc: 0.772387
# [455]	valid_0's auc: 0.772491
# [456]	valid_0's auc: 0.772387
# [457]	valid_0's auc: 0.772369
# [458]	valid_0's auc: 0.772352
# [459]	valid_0's auc: 0.771882
# [460]	valid_0's auc: 0.771917
# [461]	valid_0's auc: 0.772213
# [462]	valid_0's auc: 0.772195
# [463]	valid_0's auc: 0.772178
# [464]	valid_0's auc: 0.772108
# [465]	valid_0's auc: 0.772265
# [466]	valid_0's auc: 0.772056
# [467]	valid_0's auc: 0.772213
# [468]	valid_0's auc: 0.772091
# [469]	valid_0's auc: 0.771935
# [470]	valid_0's auc: 0.771848
# [471]	valid_0's auc: 0.771848
# [472]	valid_0's auc: 0.771952
# [473]	valid_0's auc: 0.771917
# [474]	valid_0's auc: 0.772317
# [475]	valid_0's auc: 0.772561
# [476]	valid_0's auc: 0.77263
# [477]	valid_0's auc: 0.772647
# [478]	valid_0's auc: 0.772578
# [479]	valid_0's auc: 0.77296
# [480]	valid_0's auc: 0.772995
# [481]	valid_0's auc: 0.77336
# [482]	valid_0's auc: 0.774125
# [483]	valid_0's auc: 0.773917
# [484]	valid_0's auc: 0.774108
# [485]	valid_0's auc: 0.774299
# [486]	valid_0's auc: 0.774386
# [487]	valid_0's auc: 0.774508
# [488]	valid_0's auc: 0.774664
# [489]	valid_0's auc: 0.775169
# [490]	valid_0's auc: 0.775064
# [491]	valid_0's auc: 0.775047
# [492]	valid_0's auc: 0.775308
# [493]	valid_0's auc: 0.775516
# [494]	valid_0's auc: 0.775934
# [495]	valid_0's auc: 0.776142
# [496]	valid_0's auc: 0.776177
# [497]	valid_0's auc: 0.776108
# [498]	valid_0's auc: 0.77616
# [499]	valid_0's auc: 0.77609
# [500]	valid_0's auc: 0.775829
# [501]	valid_0's auc: 0.776038
# [502]	valid_0's auc: 0.776108
# [503]	valid_0's auc: 0.776108
# [504]	valid_0's auc: 0.776368
# [505]	valid_0's auc: 0.776229
# [506]	valid_0's auc: 0.776264
# [507]	valid_0's auc: 0.776108
# [508]	valid_0's auc: 0.776229
# [509]	valid_0's auc: 0.776177
# [510]	valid_0's auc: 0.776264
# [511]	valid_0's auc: 0.776455
# [512]	valid_0's auc: 0.776351
# [513]	valid_0's auc: 0.776316
# [514]	valid_0's auc: 0.776229
# [515]	valid_0's auc: 0.776334
# [516]	valid_0's auc: 0.776403
# [517]	valid_0's auc: 0.776264
# [518]	valid_0's auc: 0.776281
# [519]	valid_0's auc: 0.77669
# [520]	valid_0's auc: 0.776916
# [521]	valid_0's auc: 0.776934
# [522]	valid_0's auc: 0.777003
# [523]	valid_0's auc: 0.777681
# [524]	valid_0's auc: 0.777751
# [525]	valid_0's auc: 0.778359
# [526]	valid_0's auc: 0.778481
# [527]	valid_0's auc: 0.778829
# [528]	valid_0's auc: 0.779246
# [529]	valid_0's auc: 0.779507
# [530]	valid_0's auc: 0.780115
# [531]	valid_0's auc: 0.780098
# [532]	valid_0's auc: 0.780011
# [533]	valid_0's auc: 0.780168
# [534]	valid_0's auc: 0.780098
# [535]	valid_0's auc: 0.780289
# [536]	valid_0's auc: 0.781211
# [537]	valid_0's auc: 0.781141
# [538]	valid_0's auc: 0.781072
# [539]	valid_0's auc: 0.781107
# [540]	valid_0's auc: 0.780967
# [541]	valid_0's auc: 0.780933
# [542]	valid_0's auc: 0.780759
# [543]	valid_0's auc: 0.780576
# [544]	valid_0's auc: 0.780472
# [545]	valid_0's auc: 0.780507
# [546]	valid_0's auc: 0.780489
# [547]	valid_0's auc: 0.780072
# [548]	valid_0's auc: 0.780107
# [549]	valid_0's auc: 0.779863
# [550]	valid_0's auc: 0.779881
# [551]	valid_0's auc: 0.779672
# [552]	valid_0's auc: 0.779776
# [553]	valid_0's auc: 0.779776
# [554]	valid_0's auc: 0.779776
# [555]	valid_0's auc: 0.779707
# [556]	valid_0's auc: 0.779724
# [557]	valid_0's auc: 0.779829
# [558]	valid_0's auc: 0.779724
# [559]	valid_0's auc: 0.77955
# [560]	valid_0's auc: 0.779411
# [561]	valid_0's auc: 0.779394
# [562]	valid_0's auc: 0.779776
# [563]	valid_0's auc: 0.779707
# [564]	valid_0's auc: 0.779481
# [565]	valid_0's auc: 0.779376
# [566]	valid_0's auc: 0.779229
# [567]	valid_0's auc: 0.779437
# [568]	valid_0's auc: 0.779107
# [569]	valid_0's auc: 0.779003
# [570]	valid_0's auc: 0.778759
# [571]	valid_0's auc: 0.778777
# [572]	valid_0's auc: 0.779037
# [573]	valid_0's auc: 0.778638
# [574]	valid_0's auc: 0.778759
# [575]	valid_0's auc: 0.778777
# [576]	valid_0's auc: 0.778603
# [577]	valid_0's auc: 0.77862
# [578]	valid_0's auc: 0.779003
# [579]	valid_0's auc: 0.779072
# [580]	valid_0's auc: 0.779376
# [581]	valid_0's auc: 0.77929
# [582]	valid_0's auc: 0.77922
# [583]	valid_0's auc: 0.77922
# [584]	valid_0's auc: 0.779116
# [585]	valid_0's auc: 0.779133
# [586]	valid_0's auc: 0.778872
# [587]	valid_0's auc: 0.778542
# [588]	valid_0's auc: 0.778524
# [589]	valid_0's auc: 0.778733
# [590]	valid_0's auc: 0.778803
# [591]	valid_0's auc: 0.77889
# [592]	valid_0's auc: 0.778872
# [593]	valid_0's auc: 0.779029
# [594]	valid_0's auc: 0.77889
# [595]	valid_0's auc: 0.77929
# [596]	valid_0's auc: 0.779159
# [597]	valid_0's auc: 0.779107
# [598]	valid_0's auc: 0.77895
# [599]	valid_0's auc: 0.778811
# [600]	valid_0's auc: 0.77902
# [601]	valid_0's auc: 0.779003
# [602]	valid_0's auc: 0.779177
# [603]	valid_0's auc: 0.779229
# [604]	valid_0's auc: 0.779194
# [605]	valid_0's auc: 0.779072
# [606]	valid_0's auc: 0.779281
# [607]	valid_0's auc: 0.779263
# [608]	valid_0's auc: 0.779281
# [609]	valid_0's auc: 0.779159
# [610]	valid_0's auc: 0.779003
# [611]	valid_0's auc: 0.77895
# [612]	valid_0's auc: 0.778777
# [613]	valid_0's auc: 0.778864
# [614]	valid_0's auc: 0.779507
# [615]	valid_0's auc: 0.779646
# [616]	valid_0's auc: 0.779594
# [617]	valid_0's auc: 0.779489
# [618]	valid_0's auc: 0.779498
# [619]	valid_0's auc: 0.779498
# [620]	valid_0's auc: 0.779637
# [621]	valid_0's auc: 0.77962
# [622]	valid_0's auc: 0.780002
# [623]	valid_0's auc: 0.780263
# [624]	valid_0's auc: 0.780646
# [625]	valid_0's auc: 0.78075
# [626]	valid_0's auc: 0.781167
# [627]	valid_0's auc: 0.781619
# [628]	valid_0's auc: 0.781359
# [629]	valid_0's auc: 0.781324
# [630]	valid_0's auc: 0.781254
# [631]	valid_0's auc: 0.781359
# [632]	valid_0's auc: 0.781393
# [633]	valid_0's auc: 0.781672
# [634]	valid_0's auc: 0.781932
# [635]	valid_0's auc: 0.781932
# [636]	valid_0's auc: 0.78195
# [637]	valid_0's auc: 0.782124
# [638]	valid_0's auc: 0.782437
# [639]	valid_0's auc: 0.782645
# [640]	valid_0's auc: 0.782524
# [641]	valid_0's auc: 0.782471
# [642]	valid_0's auc: 0.782471
# [643]	valid_0's auc: 0.782471
# [644]	valid_0's auc: 0.782471
# [645]	valid_0's auc: 0.78268
# [646]	valid_0's auc: 0.78268
# [647]	valid_0's auc: 0.782593
# [648]	valid_0's auc: 0.782698
# [649]	valid_0's auc: 0.782906
# [650]	valid_0's auc: 0.782976
# [651]	valid_0's auc: 0.782698
# [652]	valid_0's auc: 0.782611
# [653]	valid_0's auc: 0.782611
# [654]	valid_0's auc: 0.782819
# [655]	valid_0's auc: 0.783063
# [656]	valid_0's auc: 0.783132
# [657]	valid_0's auc: 0.78315
# [658]	valid_0's auc: 0.783167
# [659]	valid_0's auc: 0.783237
# [660]	valid_0's auc: 0.783237
# [661]	valid_0's auc: 0.78341
# [662]	valid_0's auc: 0.783636
# [663]	valid_0's auc: 0.783584
# [664]	valid_0's auc: 0.783862
# [665]	valid_0's auc: 0.78388
# [666]	valid_0's auc: 0.783932
# [667]	valid_0's auc: 0.784089
# [668]	valid_0's auc: 0.784158
# [669]	valid_0's auc: 0.784089
# [670]	valid_0's auc: 0.784158
# [671]	valid_0's auc: 0.784071
# [672]	valid_0's auc: 0.784193
# [673]	valid_0's auc: 0.784036
# [674]	valid_0's auc: 0.784054
# [675]	valid_0's auc: 0.784132
# [676]	valid_0's auc: 0.784045
# [677]	valid_0's auc: 0.783697
# [678]	valid_0's auc: 0.783871
# [679]	valid_0's auc: 0.783419
# [680]	valid_0's auc: 0.783645
# [681]	valid_0's auc: 0.783628
# [682]	valid_0's auc: 0.783645
# [683]	valid_0's auc: 0.783297
# [684]	valid_0's auc: 0.783245
# [685]	valid_0's auc: 0.783367
# [686]	valid_0's auc: 0.783019
# [687]	valid_0's auc: 0.782932
# [688]	valid_0's auc: 0.783071
# [689]	valid_0's auc: 0.78328
# [690]	valid_0's auc: 0.78328
# [691]	valid_0's auc: 0.78335
# [692]	valid_0's auc: 0.783176
# [693]	valid_0's auc: 0.783054
# [694]	valid_0's auc: 0.782897
# [695]	valid_0's auc: 0.783002
# [696]	valid_0's auc: 0.783002
# [697]	valid_0's auc: 0.783228
# [698]	valid_0's auc: 0.78321
# [699]	valid_0's auc: 0.783297
# [700]	valid_0's auc: 0.783228
# [701]	valid_0's auc: 0.783193
# [702]	valid_0's auc: 0.783037
# [703]	valid_0's auc: 0.783245
# [704]	valid_0's auc: 0.78321
# [705]	valid_0's auc: 0.783019
# [706]	valid_0's auc: 0.783019
# [707]	valid_0's auc: 0.783176
# [708]	valid_0's auc: 0.783071
# [709]	valid_0's auc: 0.782967
# [710]	valid_0's auc: 0.782532
# [711]	valid_0's auc: 0.782654
# [712]	valid_0's auc: 0.782793
# [713]	valid_0's auc: 0.782776
# [714]	valid_0's auc: 0.782811
# [715]	valid_0's auc: 0.782724
# [716]	valid_0's auc: 0.782776
# [717]	valid_0's auc: 0.782758
# [718]	valid_0's auc: 0.783489
# [719]	valid_0's auc: 0.783419
# [720]	valid_0's auc: 0.783523
# [721]	valid_0's auc: 0.783558
# [722]	valid_0's auc: 0.783819
# [723]	valid_0's auc: 0.783889
# [724]	valid_0's auc: 0.784219
# [725]	valid_0's auc: 0.78408
# [726]	valid_0's auc: 0.78401
# [727]	valid_0's auc: 0.783958
# [728]	valid_0's auc: 0.783941
# [729]	valid_0's auc: 0.784219
# [730]	valid_0's auc: 0.784219
# [731]	valid_0's auc: 0.784184
# [732]	valid_0's auc: 0.784115
# [733]	valid_0's auc: 0.78408
# [734]	valid_0's auc: 0.784097
# [735]	valid_0's auc: 0.784428
# [736]	valid_0's auc: 0.784202
# [737]	valid_0's auc: 0.784323
# [738]	valid_0's auc: 0.784323
# [739]	valid_0's auc: 0.784288
# [740]	valid_0's auc: 0.784375
# [741]	valid_0's auc: 0.78448
# [742]	valid_0's auc: 0.784393
# [743]	valid_0's auc: 0.784532
# [744]	valid_0's auc: 0.784532
# [745]	valid_0's auc: 0.784636
# [746]	valid_0's auc: 0.78448
# [747]	valid_0's auc: 0.784323
# [748]	valid_0's auc: 0.784254
# [749]	valid_0's auc: 0.78448
# [750]	valid_0's auc: 0.784445
# [751]	valid_0's auc: 0.784497
# [752]	valid_0's auc: 0.784654
# [753]	valid_0's auc: 0.784532
# [754]	valid_0's auc: 0.784914
# [755]	valid_0's auc: 0.784932
# [756]	valid_0's auc: 0.785001
# [757]	valid_0's auc: 0.784984
# [758]	valid_0's auc: 0.784897
# [759]	valid_0's auc: 0.785106
# [760]	valid_0's auc: 0.785019
# [761]	valid_0's auc: 0.784967
# [762]	valid_0's auc: 0.784914
# [763]	valid_0's auc: 0.784897
# [764]	valid_0's auc: 0.785001
# [765]	valid_0's auc: 0.78521
# [766]	valid_0's auc: 0.785262
# [767]	valid_0's auc: 0.785332
# [768]	valid_0's auc: 0.785262
# [769]	valid_0's auc: 0.785384
# [770]	valid_0's auc: 0.78528
# [771]	valid_0's auc: 0.785506
# [772]	valid_0's auc: 0.78554
# [773]	valid_0's auc: 0.785784
# [774]	valid_0's auc: 0.785784
# [775]	valid_0's auc: 0.785853
# [776]	valid_0's auc: 0.785853
# [777]	valid_0's auc: 0.785871
# [778]	valid_0's auc: 0.785923
# [779]	valid_0's auc: 0.786062
# [780]	valid_0's auc: 0.78601
# [781]	valid_0's auc: 0.786045
# [782]	valid_0's auc: 0.786062
# [783]	valid_0's auc: 0.786114
# [784]	valid_0's auc: 0.786166
# [785]	valid_0's auc: 0.786201
# [786]	valid_0's auc: 0.786184
# [787]	valid_0's auc: 0.786132
# [788]	valid_0's auc: 0.78634
# [789]	valid_0's auc: 0.786375
# [790]	valid_0's auc: 0.786445
# [791]	valid_0's auc: 0.786445
# [792]	valid_0's auc: 0.786636
# [793]	valid_0's auc: 0.786758
# [794]	valid_0's auc: 0.786897
# [795]	valid_0's auc: 0.786775
# [796]	valid_0's auc: 0.786775
# [797]	valid_0's auc: 0.786827
# [798]	valid_0's auc: 0.786862
# [799]	valid_0's auc: 0.787192
# [800]	valid_0's auc: 0.787192
# [801]	valid_0's auc: 0.787123
# [802]	valid_0's auc: 0.787105
# [803]	valid_0's auc: 0.787157
# [804]	valid_0's auc: 0.787192
# [805]	valid_0's auc: 0.787244
# [806]	valid_0's auc: 0.786566
# [807]	valid_0's auc: 0.786601
# [808]	valid_0's auc: 0.786966
# [809]	valid_0's auc: 0.786862
# [810]	valid_0's auc: 0.78681
# [811]	valid_0's auc: 0.786879
# [812]	valid_0's auc: 0.786358
# [813]	valid_0's auc: 0.786219
# [814]	valid_0's auc: 0.786132
# [815]	valid_0's auc: 0.786201
# [816]	valid_0's auc: 0.786305
# [817]	valid_0's auc: 0.786271
# [818]	valid_0's auc: 0.786201
# [819]	valid_0's auc: 0.786253
# [820]	valid_0's auc: 0.786392
# [821]	valid_0's auc: 0.786375
# [822]	valid_0's auc: 0.786497
# [823]	valid_0's auc: 0.786653
# [824]	valid_0's auc: 0.786723
# [825]	valid_0's auc: 0.786705
# [826]	valid_0's auc: 0.786671
# [827]	valid_0's auc: 0.786775
# [828]	valid_0's auc: 0.786879
# [829]	valid_0's auc: 0.786914
# [830]	valid_0's auc: 0.78681
# [831]	valid_0's auc: 0.786705
# [832]	valid_0's auc: 0.786844
# [833]	valid_0's auc: 0.786792
# [834]	valid_0's auc: 0.786984
# [835]	valid_0's auc: 0.787071
# [836]	valid_0's auc: 0.786931
# [837]	valid_0's auc: 0.786931
# [838]	valid_0's auc: 0.787401
# [839]	valid_0's auc: 0.787523
# [840]	valid_0's auc: 0.787627
# [841]	valid_0's auc: 0.787679
# [842]	valid_0's auc: 0.787557
# [843]	valid_0's auc: 0.787523
# [844]	valid_0's auc: 0.787314
# [845]	valid_0's auc: 0.787262
# [846]	valid_0's auc: 0.787105
# [847]	valid_0's auc: 0.787297
# [848]	valid_0's auc: 0.787297
# [849]	valid_0's auc: 0.787384
# [850]	valid_0's auc: 0.787418
# [851]	valid_0's auc: 0.787366
# [852]	valid_0's auc: 0.786497
# [853]	valid_0's auc: 0.786792
# [854]	valid_0's auc: 0.786705
# [855]	valid_0's auc: 0.786984
# [856]	valid_0's auc: 0.785958
# [857]	valid_0's auc: 0.785958
# [858]	valid_0's auc: 0.78601
# [859]	valid_0's auc: 0.786288
# [860]	valid_0's auc: 0.78634
# [861]	valid_0's auc: 0.78634
# [862]	valid_0's auc: 0.786427
# [863]	valid_0's auc: 0.786445
# [864]	valid_0's auc: 0.786392
# [865]	valid_0's auc: 0.78634
# [866]	valid_0's auc: 0.786375
# [867]	valid_0's auc: 0.786358
# [868]	valid_0's auc: 0.786219
# [869]	valid_0's auc: 0.786236
# [870]	valid_0's auc: 0.786305
# [871]	valid_0's auc: 0.786271
# [872]	valid_0's auc: 0.786201
# [873]	valid_0's auc: 0.786323
# [874]	valid_0's auc: 0.786253
# [875]	valid_0's auc: 0.786219
# [876]	valid_0's auc: 0.786201
# [877]	valid_0's auc: 0.786045
# [878]	valid_0's auc: 0.786045
# [879]	valid_0's auc: 0.785975
# [880]	valid_0's auc: 0.786027
# [881]	valid_0's auc: 0.786027
# [882]	valid_0's auc: 0.786079
# [883]	valid_0's auc: 0.78601
# [884]	valid_0's auc: 0.786114
# [885]	valid_0's auc: 0.785819
# [886]	valid_0's auc: 0.785853
# [887]	valid_0's auc: 0.785801
# [888]	valid_0's auc: 0.785732
# [889]	valid_0's auc: 0.785732
# [890]	valid_0's auc: 0.785819
# [891]	valid_0's auc: 0.785575
# [892]	valid_0's auc: 0.785766
# [893]	valid_0's auc: 0.785819
# [894]	valid_0's auc: 0.785958
# [895]	valid_0's auc: 0.785975
# [896]	valid_0's auc: 0.786305
# [897]	valid_0's auc: 0.786045
# [898]	valid_0's auc: 0.786149
# [899]	valid_0's auc: 0.785992
# [900]	valid_0's auc: 0.785923
# [901]	valid_0's auc: 0.786236
# [902]	valid_0's auc: 0.786584
# [903]	valid_0's auc: 0.786775
# [904]	valid_0's auc: 0.786792
# [905]	valid_0's auc: 0.786966
# [906]	valid_0's auc: 0.786966
# [907]	valid_0's auc: 0.787175
# [908]	valid_0's auc: 0.787314
# [909]	valid_0's auc: 0.787453
# [910]	valid_0's auc: 0.787157
# [911]	valid_0's auc: 0.787314
# [912]	valid_0's auc: 0.787297
# [913]	valid_0's auc: 0.787349
# [914]	valid_0's auc: 0.787523
# [915]	valid_0's auc: 0.787766
# [916]	valid_0's auc: 0.787644
# [917]	valid_0's auc: 0.786862
# [918]	valid_0's auc: 0.786844
# [919]	valid_0's auc: 0.786601
# [920]	valid_0's auc: 0.78661
# [921]	valid_0's auc: 0.786436
# [922]	valid_0's auc: 0.786192
# [923]	valid_0's auc: 0.785966
# [924]	valid_0's auc: 0.786001
# [925]	valid_0's auc: 0.785793
# [926]	valid_0's auc: 0.785758
# [927]	valid_0's auc: 0.78581
# [928]	valid_0's auc: 0.785688
# [929]	valid_0's auc: 0.785619
# [930]	valid_0's auc: 0.78574
# [931]	valid_0's auc: 0.785584
# [932]	valid_0's auc: 0.785827
# [933]	valid_0's auc: 0.785758
# [934]	valid_0's auc: 0.78574
# [935]	valid_0's auc: 0.785619
# [936]	valid_0's auc: 0.785688
# [937]	valid_0's auc: 0.785775
# [938]	valid_0's auc: 0.785827
# [939]	valid_0's auc: 0.786071
# [940]	valid_0's auc: 0.786053
# [941]	valid_0's auc: 0.786384
# [942]	valid_0's auc: 0.786418
# [943]	valid_0's auc: 0.786749
# [944]	valid_0's auc: 0.786679
# [945]	valid_0's auc: 0.786662
# [946]	valid_0's auc: 0.787131
# [947]	valid_0's auc: 0.787566
# [948]	valid_0's auc: 0.787949
# [949]	valid_0's auc: 0.788001
# [950]	valid_0's auc: 0.788036
# [951]	valid_0's auc: 0.788036
# [952]	valid_0's auc: 0.78774
# [953]	valid_0's auc: 0.787775
# [954]	valid_0's auc: 0.787775
# [955]	valid_0's auc: 0.787966
# [956]	valid_0's auc: 0.788001
# [957]	valid_0's auc: 0.787983
# [958]	valid_0's auc: 0.78807
# [959]	valid_0's auc: 0.788001
# [960]	valid_0's auc: 0.787983
# [961]	valid_0's auc: 0.787879
# [962]	valid_0's auc: 0.787966
# [963]	valid_0's auc: 0.787966
# [964]	valid_0's auc: 0.788036
# [965]	valid_0's auc: 0.788192
# [966]	valid_0's auc: 0.788279
# [967]	valid_0's auc: 0.788157
# [968]	valid_0's auc: 0.78807
# [969]	valid_0's auc: 0.78814
# [970]	valid_0's auc: 0.788157
# [971]	valid_0's auc: 0.788244
# [972]	valid_0's auc: 0.788401
# [973]	valid_0's auc: 0.788592
# [974]	valid_0's auc: 0.78854
# [975]	valid_0's auc: 0.788522
# [976]	valid_0's auc: 0.788575
# [977]	valid_0's auc: 0.788679
# [978]	valid_0's auc: 0.788557
# [979]	valid_0's auc: 0.788435
# [980]	valid_0's auc: 0.788418
# [981]	valid_0's auc: 0.788244
# [982]	valid_0's auc: 0.788314
# [983]	valid_0's auc: 0.788105
# [984]	valid_0's auc: 0.788018
# [985]	valid_0's auc: 0.788088
# [986]	valid_0's auc: 0.788053
# [987]	valid_0's auc: 0.788001
# [988]	valid_0's auc: 0.788001
# [989]	valid_0's auc: 0.787966
# [990]	valid_0's auc: 0.787705
# [991]	valid_0's auc: 0.787601
# [992]	valid_0's auc: 0.787549
# [993]	valid_0's auc: 0.787479
# [994]	valid_0's auc: 0.787497
# [995]	valid_0's auc: 0.78741
# [996]	valid_0's auc: 0.787688
# [997]	valid_0's auc: 0.787514
# [998]	valid_0's auc: 0.787236
# [999]	valid_0's auc: 0.787166
# [1000]	valid_0's auc: 0.787166
# [1001]	valid_0's auc: 0.787253
# [1002]	valid_0's auc: 0.787427
# [1003]	valid_0's auc: 0.78741
# [1004]	valid_0's auc: 0.787253
# [1005]	valid_0's auc: 0.786923
# [1006]	valid_0's auc: 0.787044
# [1007]	valid_0's auc: 0.787462
# [1008]	valid_0's auc: 0.78727
# [1009]	valid_0's auc: 0.787253
# [1010]	valid_0's auc: 0.787288
# [1011]	valid_0's auc: 0.78727
# [1012]	valid_0's auc: 0.787305
# [1013]	valid_0's auc: 0.787288
# [1014]	valid_0's auc: 0.787323
# [1015]	valid_0's auc: 0.787375
# [1016]	valid_0's auc: 0.787357
# [1017]	valid_0's auc: 0.787357
# [1018]	valid_0's auc: 0.787253
# [1019]	valid_0's auc: 0.787236
# [1020]	valid_0's auc: 0.787392
# [1021]	valid_0's auc: 0.787583
# [1022]	valid_0's auc: 0.787862
# [1023]	valid_0's auc: 0.788001
# [1024]	valid_0's auc: 0.788418
# [1025]	valid_0's auc: 0.788435
# [1026]	valid_0's auc: 0.788418
# [1027]	valid_0's auc: 0.788366
# [1028]	valid_0's auc: 0.788331
# [1029]	valid_0's auc: 0.788505
# [1030]	valid_0's auc: 0.788383
# [1031]	valid_0's auc: 0.788418
# [1032]	valid_0's auc: 0.788418
# [1033]	valid_0's auc: 0.788522
# [1034]	valid_0's auc: 0.788505
# [1035]	valid_0's auc: 0.788488
# [1036]	valid_0's auc: 0.788557
# [1037]	valid_0's auc: 0.788557
# [1038]	valid_0's auc: 0.788435
# [1039]	valid_0's auc: 0.788453
# [1040]	valid_0's auc: 0.788748
# [1041]	valid_0's auc: 0.788748
# [1042]	valid_0's auc: 0.788905
# [1043]	valid_0's auc: 0.788835
# [1044]	valid_0's auc: 0.788818
# [1045]	valid_0's auc: 0.789287
# [1046]	valid_0's auc: 0.789218
# [1047]	valid_0's auc: 0.789392
# [1048]	valid_0's auc: 0.789305
# [1049]	valid_0's auc: 0.789131
# [1050]	valid_0's auc: 0.789061
# [1051]	valid_0's auc: 0.789166
# [1052]	valid_0's auc: 0.789322
# [1053]	valid_0's auc: 0.789548
# [1054]	valid_0's auc: 0.789566
# [1055]	valid_0's auc: 0.789427
# [1056]	valid_0's auc: 0.789583
# [1057]	valid_0's auc: 0.7896
# [1058]	valid_0's auc: 0.789653
# [1059]	valid_0's auc: 0.789635
# [1060]	valid_0's auc: 0.789687
# [1061]	valid_0's auc: 0.789653
# [1062]	valid_0's auc: 0.78967
# [1063]	valid_0's auc: 0.789792
# [1064]	valid_0's auc: 0.789774
# [1065]	valid_0's auc: 0.789722
# [1066]	valid_0's auc: 0.789566
# [1067]	valid_0's auc: 0.7896
# [1068]	valid_0's auc: 0.78967
# [1069]	valid_0's auc: 0.789792
# [1070]	valid_0's auc: 0.789826
# [1071]	valid_0's auc: 0.790018
# [1072]	valid_0's auc: 0.790053
# [1073]	valid_0's auc: 0.79007
# [1074]	valid_0's auc: 0.79007
# [1075]	valid_0's auc: 0.79007
# [1076]	valid_0's auc: 0.790087
# [1077]	valid_0's auc: 0.790174
# [1078]	valid_0's auc: 0.790157
# [1079]	valid_0's auc: 0.790035
# [1080]	valid_0's auc: 0.789966
# [1081]	valid_0's auc: 0.790105
# [1082]	valid_0's auc: 0.79007
# [1083]	valid_0's auc: 0.790209
# [1084]	valid_0's auc: 0.790452
# [1085]	valid_0's auc: 0.790574
# [1086]	valid_0's auc: 0.790748
# [1087]	valid_0's auc: 0.790939
# [1088]	valid_0's auc: 0.791061
# [1089]	valid_0's auc: 0.791183
# [1090]	valid_0's auc: 0.791513
# [1091]	valid_0's auc: 0.791704
# [1092]	valid_0's auc: 0.791687
# [1093]	valid_0's auc: 0.791722
# [1094]	valid_0's auc: 0.791687
# [1095]	valid_0's auc: 0.791548
# [1096]	valid_0's auc: 0.791548
# [1097]	valid_0's auc: 0.79153
# [1098]	valid_0's auc: 0.791809
# [1099]	valid_0's auc: 0.792139
# [1100]	valid_0's auc: 0.792174
# [1101]	valid_0's auc: 0.792104
# [1102]	valid_0's auc: 0.792261
# [1103]	valid_0's auc: 0.791983
# [1104]	valid_0's auc: 0.791948
# [1105]	valid_0's auc: 0.791739
# [1106]	valid_0's auc: 0.791496
# [1107]	valid_0's auc: 0.7916
# [1108]	valid_0's auc: 0.79167
# [1109]	valid_0's auc: 0.791357
# [1110]	valid_0's auc: 0.791496
# [1111]	valid_0's auc: 0.791496
# [1112]	valid_0's auc: 0.791687
# [1113]	valid_0's auc: 0.791617
# [1114]	valid_0's auc: 0.791757
# [1115]	valid_0's auc: 0.791704
# [1116]	valid_0's auc: 0.79167
# [1117]	valid_0's auc: 0.791757
# [1118]	valid_0's auc: 0.791826
# [1119]	valid_0's auc: 0.791826
# [1120]	valid_0's auc: 0.791826
# [1121]	valid_0's auc: 0.791826
# [1122]	valid_0's auc: 0.792052
# [1123]	valid_0's auc: 0.792035
# [1124]	valid_0's auc: 0.792156
# [1125]	valid_0's auc: 0.792278
# [1126]	valid_0's auc: 0.792487
# [1127]	valid_0's auc: 0.792591
# [1128]	valid_0's auc: 0.792574
# [1129]	valid_0's auc: 0.792591
# [1130]	valid_0's auc: 0.792626
# [1131]	valid_0's auc: 0.792678
# [1132]	valid_0's auc: 0.792765
# [1133]	valid_0's auc: 0.792817
# [1134]	valid_0's auc: 0.792835
# [1135]	valid_0's auc: 0.792956
# [1136]	valid_0's auc: 0.792921
# [1137]	valid_0's auc: 0.792765
# [1138]	valid_0's auc: 0.792765
# [1139]	valid_0's auc: 0.792748
# [1140]	valid_0's auc: 0.792748
# [1141]	valid_0's auc: 0.792817
# [1142]	valid_0's auc: 0.792956
# [1143]	valid_0's auc: 0.793182
# [1144]	valid_0's auc: 0.7936
# [1145]	valid_0's auc: 0.793617
# [1146]	valid_0's auc: 0.793634
# [1147]	valid_0's auc: 0.793773
# [1148]	valid_0's auc: 0.793687
# [1149]	valid_0's auc: 0.793739
# [1150]	valid_0's auc: 0.793513
# [1151]	valid_0's auc: 0.793478
# [1152]	valid_0's auc: 0.793391
# [1153]	valid_0's auc: 0.793408
# [1154]	valid_0's auc: 0.793539
# [1155]	valid_0's auc: 0.793487
# [1156]	valid_0's auc: 0.793417
# [1157]	valid_0's auc: 0.793156
# [1158]	valid_0's auc: 0.793243
# [1159]	valid_0's auc: 0.793261
# [1160]	valid_0's auc: 0.793417
# [1161]	valid_0's auc: 0.793504
# [1162]	valid_0's auc: 0.793765
# [1163]	valid_0's auc: 0.793817
# [1164]	valid_0's auc: 0.794008
# [1165]	valid_0's auc: 0.793921
# [1166]	valid_0's auc: 0.793921
# [1167]	valid_0's auc: 0.793886
# [1168]	valid_0's auc: 0.793991
# [1169]	valid_0's auc: 0.793921
# [1170]	valid_0's auc: 0.793921
# [1171]	valid_0's auc: 0.79406
# [1172]	valid_0's auc: 0.79406
# [1173]	valid_0's auc: 0.794008
# [1174]	valid_0's auc: 0.793991
# [1175]	valid_0's auc: 0.793956
# [1176]	valid_0's auc: 0.794217
# [1177]	valid_0's auc: 0.794113
# [1178]	valid_0's auc: 0.794026
# [1179]	valid_0's auc: 0.794008
# [1180]	valid_0's auc: 0.7938
# [1181]	valid_0's auc: 0.793939
# [1182]	valid_0's auc: 0.794095
# [1183]	valid_0's auc: 0.794113
# [1184]	valid_0's auc: 0.794182
# [1185]	valid_0's auc: 0.794026
# [1186]	valid_0's auc: 0.794
# [1187]	valid_0's auc: 0.793895
# [1188]	valid_0's auc: 0.793895
# [1189]	valid_0's auc: 0.793791
# [1190]	valid_0's auc: 0.793808
# [1191]	valid_0's auc: 0.793965
# [1192]	valid_0's auc: 0.794017
# [1193]	valid_0's auc: 0.794017
# [1194]	valid_0's auc: 0.794052
# [1195]	valid_0's auc: 0.793947
# [1196]	valid_0's auc: 0.793878
# [1197]	valid_0's auc: 0.793947
# [1198]	valid_0's auc: 0.79393
# [1199]	valid_0's auc: 0.79386
# [1200]	valid_0's auc: 0.793826
# [1201]	valid_0's auc: 0.793808
# [1202]	valid_0's auc: 0.793756
# [1203]	valid_0's auc: 0.793739
# [1204]	valid_0's auc: 0.793687
# [1205]	valid_0's auc: 0.793652
# [1206]	valid_0's auc: 0.793582
# [1207]	valid_0's auc: 0.793547
# [1208]	valid_0's auc: 0.793582
# [1209]	valid_0's auc: 0.793652
# [1210]	valid_0's auc: 0.793634
# [1211]	valid_0's auc: 0.793513
# [1212]	valid_0's auc: 0.793513
# [1213]	valid_0's auc: 0.793252
# [1214]	valid_0's auc: 0.7932
# [1215]	valid_0's auc: 0.793182
# [1216]	valid_0's auc: 0.792904
# [1217]	valid_0's auc: 0.792921
# [1218]	valid_0's auc: 0.792974
# [1219]	valid_0's auc: 0.793208
# [1220]	valid_0's auc: 0.793121
# [1221]	valid_0's auc: 0.793104
# [1222]	valid_0's auc: 0.793121
# [1223]	valid_0's auc: 0.793034
# [1224]	valid_0's auc: 0.793087
# [1225]	valid_0's auc: 0.793139
# [1226]	valid_0's auc: 0.793087
# [1227]	valid_0's auc: 0.793034
# [1228]	valid_0's auc: 0.793
# [1229]	valid_0's auc: 0.792478
# [1230]	valid_0's auc: 0.792322
# [1231]	valid_0's auc: 0.792235
# [1232]	valid_0's auc: 0.792026
# [1233]	valid_0's auc: 0.792252
# [1234]	valid_0's auc: 0.792339
# [1235]	valid_0's auc: 0.792374
# [1236]	valid_0's auc: 0.79253
# [1237]	valid_0's auc: 0.792443
# [1238]	valid_0's auc: 0.792565
# [1239]	valid_0's auc: 0.792426
# [1240]	valid_0's auc: 0.792426
# [1241]	valid_0's auc: 0.792391
# [1242]	valid_0's auc: 0.792478
# [1243]	valid_0's auc: 0.792461
# [1244]	valid_0's auc: 0.792322
# [1245]	valid_0's auc: 0.792269
# [1246]	valid_0's auc: 0.792078
# [1247]	valid_0's auc: 0.791956
# [1248]	valid_0's auc: 0.792009
# [1249]	valid_0's auc: 0.792374
# [1250]	valid_0's auc: 0.7922
# [1251]	valid_0's auc: 0.792269
# [1252]	valid_0's auc: 0.792113
# [1253]	valid_0's auc: 0.791991
# [1254]	valid_0's auc: 0.792096
# [1255]	valid_0's auc: 0.792148
# [1256]	valid_0's auc: 0.792061
# [1257]	valid_0's auc: 0.792061
# [1258]	valid_0's auc: 0.792061
# [1259]	valid_0's auc: 0.792078
# [1260]	valid_0's auc: 0.791887
# [1261]	valid_0's auc: 0.791643
# [1262]	valid_0's auc: 0.791678
# [1263]	valid_0's auc: 0.791383
# [1264]	valid_0's auc: 0.791331
# [1265]	valid_0's auc: 0.791139
# [1266]	valid_0's auc: 0.791052
# [1267]	valid_0's auc: 0.791052
# [1268]	valid_0's auc: 0.791226
# [1269]	valid_0's auc: 0.791331
# [1270]	valid_0's auc: 0.791383
# [1271]	valid_0's auc: 0.791574
# [1272]	valid_0's auc: 0.791643
# [1273]	valid_0's auc: 0.791574
# [1274]	valid_0's auc: 0.791626
# [1275]	valid_0's auc: 0.79173
# [1276]	valid_0's auc: 0.791678
# Early stopping, best iteration is:
# [1176]	valid_0's auc: 0.794217

# %%
predictions = model.predict(all_features)
df_all['sentiment_pred'] = predictions
df_all['sentiment_pred_class'] = df_all['sentiment_pred'].apply(lambda x: round(x))

# %%
df_dublin['sentiment_pred'] = model.predict(dublin_features)
df_dublin['sentiment_pred_class'] = df_dublin['sentiment_pred'].apply(lambda x: round(x))

# %% [markdown]
# ### Metrics Train

# %%
y_hat = df_all.loc[df_all['split']=="train", "sentiment"]
y_pred = df_all.loc[df_all['split']=="train", "sentiment_pred_class"]
evaluate_model(y_hat, y_pred)
# Out:
# [[38034 11958]
#  [ 8505 41503]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79     49992
#            1       0.78      0.83      0.80     50008
#
#     accuracy                           0.80    100000
#    macro avg       0.80      0.80      0.80    100000
# weighted avg       0.80      0.80      0.80    100000
#
# Accuracy Score: 0.795

# %% [markdown]
# ### Metrics Test

# %%
y_hat = df_all.loc[(df_all['split']=="test") & (df_all['sentiment']!=-1), "sentiment"]
y_pred = df_all.loc[(df_all['split']=="test") & (df_all['sentiment']!=-1), "sentiment_pred_class"]
evaluate_model(y_hat, y_pred)
# Out:
# [[127  50]
#  [ 28 154]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77       177
#            1       0.75      0.85      0.80       182
#
#     accuracy                           0.78       359
#    macro avg       0.79      0.78      0.78       359
# weighted avg       0.79      0.78      0.78       359
#
# Accuracy Score: 0.783
# AUC: 0.782

# %% [markdown]
# ### Metrics Dublin dataset

# %%
y_hat = df_dublin.loc[(df_dublin['sentiment']!=-1), "sentiment"]
y_pred = df_dublin.loc[(df_dublin['sentiment']!=-1), "sentiment_pred_class"]
evaluate_model(y_hat, y_pred)
# Out:
# [[648 352]
#  [387 613]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.65      0.64      1000
#            1       0.64      0.61      0.62      1000
#
#     accuracy                           0.63      2000
#    macro avg       0.63      0.63      0.63      2000
# weighted avg       0.63      0.63      0.63      2000
#
# Accuracy Score: 0.630

# %% [markdown]
# ### Metrics by category

# %%
for category in df_dublin['category'].unique():
    print(category)
    y_hat = df_dublin.loc[(df_dublin['sentiment']!=-1) & (df_dublin['category']!=category), "sentiment"]
    y_pred = df_dublin.loc[(df_dublin['sentiment']!=-1) & (df_dublin['category']!=category), "sentiment_pred_class"]
    evaluate_model(y_hat, y_pred)
# Out:
# Public Spaces
# [[642 345]
#  [383 609]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.65      0.64       987
#            1       0.64      0.61      0.63       992
#
#     accuracy                           0.63      1979
#    macro avg       0.63      0.63      0.63      1979
# weighted avg       0.63      0.63      0.63      1979
#
# Accuracy Score: 0.632
# Community and Culture
# [[570 288]
#  [304 410]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.66      0.66       858
#            1       0.59      0.57      0.58       714
#
#     accuracy                           0.62      1572
#    macro avg       0.62      0.62      0.62      1572
# weighted avg       0.62      0.62      0.62      1572
#
# Accuracy Score: 0.623
# Mobility
# [[473 268]
#  [304 511]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.62       741
#            1       0.66      0.63      0.64       815
#
#     accuracy                           0.63      1556
#    macro avg       0.63      0.63      0.63      1556
# weighted avg       0.63      0.63      0.63      1556
#
# Accuracy Score: 0.632
# Poverty and Homelessness
# [[570 327]
#  [363 588]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.62       897
#            1       0.64      0.62      0.63       951
#
#     accuracy                           0.63      1848
#    macro avg       0.63      0.63      0.63      1848
# weighted avg       0.63      0.63      0.63      1848
#
# Accuracy Score: 0.627
# Safety
# [[591 314]
#  [352 574]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.65      0.64       905
#            1       0.65      0.62      0.63       926
#
#     accuracy                           0.64      1831
#    macro avg       0.64      0.64      0.64      1831
# weighted avg       0.64      0.64      0.64      1831
#
# Accuracy Score: 0.636
# Tourism and Hospitality
# [[626 335]
#  [371 582]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.65      0.64       961
#            1       0.63      0.61      0.62       953
#
#     accuracy                           0.63      1914
#    macro avg       0.63      0.63      0.63      1914
# weighted avg       0.63      0.63      0.63      1914
#
# Accuracy Score: 0.631
# Utilities
# [[633 347]
#  [383 604]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.63       980
#            1       0.64      0.61      0.62       987
#
#     accuracy                           0.63      1967
#    macro avg       0.63      0.63      0.63      1967
# weighted avg       0.63      0.63      0.63      1967
#
# Accuracy Score: 0.629
# Governance
# [[608 330]
#  [369 593]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.63       938
#            1       0.64      0.62      0.63       962
#
#     accuracy                           0.63      1900
#    macro avg       0.63      0.63      0.63      1900
# weighted avg       0.63      0.63      0.63      1900
#
# Accuracy Score: 0.632
# Housing
# [[590 331]
#  [360 551]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.64      0.63       921
#            1       0.62      0.60      0.61       911
#
#     accuracy                           0.62      1832
#    macro avg       0.62      0.62      0.62      1832
# weighted avg       0.62      0.62      0.62      1832
#
# Accuracy Score: 0.623
# Education
# [[635 351]
#  [373 593]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.64       986
#            1       0.63      0.61      0.62       966
#
#     accuracy                           0.63      1952
#    macro avg       0.63      0.63      0.63      1952
# weighted avg       0.63      0.63      0.63      1952
#
# Accuracy Score: 0.629
# Environment
# [[615 325]
#  [356 567]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.65      0.64       940
#            1       0.64      0.61      0.62       923
#
#     accuracy                           0.63      1863
#    macro avg       0.63      0.63      0.63      1863
# weighted avg       0.63      0.63      0.63      1863
#
# Accuracy Score: 0.634
# Infrastructure
# [[606 334]
#  [360 594]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.64       940
#            1       0.64      0.62      0.63       954
#
#     accuracy                           0.63      1894
#    macro avg       0.63      0.63      0.63      1894
# weighted avg       0.63      0.63      0.63      1894
#
# Accuracy Score: 0.634
# Economic Development
# [[643 342]
#  [377 598]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.65      0.64       985
#            1       0.64      0.61      0.62       975
#
#     accuracy                           0.63      1960
#    macro avg       0.63      0.63      0.63      1960
# weighted avg       0.63      0.63      0.63      1960
#
# Accuracy Score: 0.633
# Health
# [[643 349]
#  [384 609]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.65      0.64       992
#            1       0.64      0.61      0.62       993
#
#     accuracy                           0.63      1985
#    macro avg       0.63      0.63      0.63      1985
# weighted avg       0.63      0.63      0.63      1985
#
# Accuracy Score: 0.631
# Social Inclusion
# [[627 342]
#  [379 599]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.63       969
#            1       0.64      0.61      0.62       978
#
#     accuracy                           0.63      1947
#    macro avg       0.63      0.63      0.63      1947
# weighted avg       0.63      0.63      0.63      1947
#
# Accuracy Score: 0.630

# %%
df_dublin['sentiment_pred_class'] = df_dublin['sentiment_pred'].astype(int)

# %% [markdown]
# # SHAP values of baseline model with test dataset

# %%
explainer = shap.TreeExplainer(model,
                                 df_test_features)
shap_values = explainer.shap_values(df_test_features)
X_test_array = test_features.toarray()
shap.summary_plot(shap_values,
                  X_test_array,
                  feature_names=word_vectorizer.get_feature_names())
# Out:
#  99%|===================| 495/498 [00:50<00:00]

# %% [markdown]
# # SHAP values of baseline model with dublin dataset

# %%
explainer = shap.TreeExplainer(model,
                                 df_dublin_features)
shap_values = explainer.shap_values(df_dublin_features)
X_test_array = dublin_features.toarray()
shap.summary_plot(shap_values,
                  X_test_array,
                  feature_names=word_vectorizer.get_feature_names())
# Out:
# 100%|===================| 2993/3000 [05:03<00:00]

# %% [markdown]
# # SHAP values of baseline model with test dataset only with right predictions

# %%
mask = df_dublin[df_dublin['sentiment'] == df_dublin['sentiment_pred_class']].index

explainer = shap.TreeExplainer(model,
                                 df_dublin_features.loc[mask])
shap_values = explainer.shap_values(df_dublin_features.loc[mask])
X_test_array = dublin_features[mask].toarray()
shap.summary_plot(shap_values,
                  X_test_array,
                  feature_names=word_vectorizer.get_feature_names())
# Out:
#  99%|===================| 991/1000 [01:40<00:00]

# %% [markdown]
# # SHAP values of baseline model with test dataset only with wrong predictions

# %%
mask = df_dublin[df_dublin['sentiment'] != df_dublin['sentiment_pred_class']].index

explainer = shap.TreeExplainer(model,
                                 df_dublin_features.loc[mask])
shap_values = explainer.shap_values(df_dublin_features.loc[mask])
X_test_array = dublin_features[mask].toarray()
shap.summary_plot(shap_values,
                  X_test_array,
                  feature_names=word_vectorizer.get_feature_names())
# Out:
# 100%|===================| 1999/2000 [03:20<00:00]

# %% [markdown]
# # SHAP values for individual cases of wrong predictions

# %%
for i in range(N_TWEET_PRINT):
    y_true_n = df_dublin[df_dublin['sentiment'] != df_dublin['sentiment_pred_class']].loc[mask[i], 'sentiment']
    y_pred_n = df_dublin[df_dublin['sentiment'] != df_dublin['sentiment_pred_class']].loc[mask[i], 'sentiment_pred_class']
    print(f"Tweet {i+1}/{N_TWEET_PRINT}")
    print(f"Real sentiment: {y_true_n}")
    print(f"Predicted sentiment: {y_pred_n}")
    print(df_dublin[df_dublin['sentiment'] != df_dublin['sentiment_pred_class']].loc[mask[i], 'text'])
    shap.plots._waterfall.waterfall_legacy(explainer.expected_value, shap_values[i], feature_names=word_vectorizer.get_feature_names())
# Out:
# Tweet 1/10
# Real sentiment: 1
# Predicted sentiment: 0
# @DanMulhall @EamonnMallie @MoLI_Museum .@DubCityCouncil #parks dept does great job all year round. Grma - I regularly walk through St Stephenâs Green &amp; am always grateful #Dublin
# Tweet 2/10
# Real sentiment: 1
# Predicted sentiment: 0
# Love my city and community!! Rallying together for what is right ðð½ðð½ðð½ðð½ @selenatwest @NinaWest
#
# Supporters rally outside Delaware Drag 101 class https://t.co/sCNRDZ9cvp
# Tweet 3/10
# Real sentiment: 1
# Predicted sentiment: 0
# Bringing shared #micromobility e-bike &amp; e-scooter solutions to bear on Dublinâs traffic congestion, will help our ranking enormously
#
# Looking forward to @Dub_Bleeper @MobyMove new schemes + arrival of shared scooter operators in time also @smartdublin @jcudden @LordMayorDublin https://t.co/Adw9XsJOTQ
# Tweet 4/10
# Real sentiment: 1
# Predicted sentiment: 0
# @rothairisbeoir @__kbaker__ @cullen_ellen @willdesigndub @dublincycling @DubCityCouncil Aw man. And there I was, for just a moment, so happy.
# Tweet 5/10
# Real sentiment: 1
# Predicted sentiment: 0
# @OConnorOisin @TUDublinEPS @IrishPedestrian @LorraineFitzsim @UCDRUP @DublinCommuters High Street  .. 6 lane urban motorway through Medieval city
# Tweet 6/10
# Real sentiment: 1
# Predicted sentiment: 0
# RT @ChildRightsIRL: In 1919, The Democratic Programme of the First DÃ¡il promised âIt shall be the first duty of the Government of the Repubâ¦
# Tweet 7/10
# Real sentiment: 1
# Predicted sentiment: 0
# Evo Morales is still the legal president of Bolivia as his resignation was not legally accepted by an elected government. The UN must act now,
# Tweet 8/10
# Real sentiment: 1
# Predicted sentiment: 0
# @ShayBrennan @dlrcc @DublinVelo2019 @DublinCommuters @dlrcycling @IBIKEDublin @Cyclistie @dlbcycles @Greenaer We might be able to help with the clothing issueð
# Tweet 9/10
# Real sentiment: 1
# Predicted sentiment: 0
# @DubCham Finally. Good on you Dublin Chamber - this will solve the long standing white water rafting crisis that has gripped our beloved capital.
# Tweet 10/10
# Real sentiment: 1
# Predicted sentiment: 0
# @Ciara87C Dublin city council must have seen that mumsnet review saying thereâs nothing to do in Dublin and decided to take immediate action.  Keeping the tourists happy should be the top priority.
